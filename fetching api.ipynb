# %%
import requests
import json
api_request=requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=200&convert=USD&CMC_PRO_API_KEY=332c0fe8-fcfe-410a-a7bb-85c61fe285ff")
api=json.loads(api_request.content)
print(api)
# Out:
# {'status': {'timestamp': '2020-05-21T11:12:50.263Z', 'error_code': 0, 'error_message': None, 'elapsed': 25, 'credit_count': 1, 'notice': None}, 'data': [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'slug': 'bitcoin', 'num_market_pairs': 8279, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18382343, 'total_supply': 18382343, 'platform': None, 'cmc_rank': 1, 'last_updated': '2020-05-21T11:11:31.000Z', 'quote': {'USD': {'price': 9360.24855357, 'volume_24h': 37708175766.5908, 'percent_change_1h': 0.206656, 'percent_change_24h': -4.02443, 'percent_change_7d': -2.05006, 'market_cap': 172063299476.9776, 'last_updated': '2020-05-21T11:11:31.000Z'}}}, {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'num_market_pairs': 5189, 'date_added': '2015-08-07T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': None, 'circulating_supply': 111017740.6865, 'total_supply': 111017740.6865, 'platform': None, 'cmc_rank': 2, 'last_updated': '2020-05-21T11:11:19.000Z', 'quote': {'USD': {'price': 207.748651155, 'volume_24h': 12741037288.3782, 'percent_change_1h': 0.214376, 'percent_change_24h': -2.72489, 'percent_change_7d': 3.50128, 'market_cap': 23063785881.89594, 'last_updated': '2020-05-21T11:11:19.000Z'}}}, {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'slug': 'tether', 'num_market_pairs': 5069, 'date_added': '2015-02-25T00:00:00.000Z', 'tags': [], 'max_supply': None, 'circulating_supply': 8798069379.47, 'total_supply': 9079177441.54, 'platform': {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'slug': 'ethereum', 'token_address': '31'}, 'cmc_rank': 3, 'last_updated': '2020-05-21T11:11:19.000Z', 'quote': {'USD': {'price': 1.00101747593, 'volume_24h': 45354039737.3531, 'percent_change_1h': -0.065363, 'percent_change_24h': 0.0806101, 'percent_change_7d': 0.349417, 'market_cap': 8807021203.294079, 'last_updated': '2020-05-21T11:11:19.000Z'}}}, {'id': 52, 'name': 'XRP', 'symbol': 'XRP', 'slug': 'xrp', 'num_market_pairs': 563, 'date_added': '2013-08-04T00:00:00.000Z', 'tags': [], 'max_supply': 100000000000, 'circulating_supply': 44112853111, 'total_supply': 99990976125, 'platform': None, 'cmc_rank': 4, 'last_updated': '2020-05-21T11:12:04.000Z', 'quote': {'USD': {'price': 0.199660512708, 'volume_24h': 1731624965.26576, 'percent_change_1h': 0.223561, 'percent_change_24h': -2.57598, 'percent_change_7d': -1.19719, 'market_cap': 8807594869.154953, 'last_updated': '2020-05-21T11:12:04.000Z'}}}, {'id': 1831, 'name': 'Bitcoin Cash', 'symbol': 'BCH', 'slug': 'bitcoin-cash', 'num_market_pairs': 496, 'date_added': '2017-07-23T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18413062.5, 'total_supply': 18413062.5, 'platform': None, 'cmc_rank': 5, 'last_updated': '2020-05-21T11:12:06.000Z', 'quote': {'USD': {'price': 237.338658166, 'volume_24h': 2849013673.64762, 'percent_change_1h': 0.223046, 'percent_change_24h': -3.55476, 'percent_change_7d': -1.19572, 'market_cap': 4370131546.476693, 'last_updated': '2020-05-21T11:12:06.000Z'}}}, {'id': 3602, 'name': 'Bitcoin SV', 'symbol': 'BSV', 'slug': 'bitcoin-sv', 'num_market_pairs': 193, 'date_added': '2018-11-09T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 21000000, 'circulating_supply': 18411589.5819233, 'total_supply': 18411589.5819233, 'platform': None, 'cmc_rank': 6, 'last_updated': '2020-05-21T11:12:12.000Z', 'quote': {'USD': {'price': 197.028400969, 'volume_24h': 1757136057.03729, 'percent_change_1h': 0.350469, 'percent_change_24h': -2.15996, 'percent_change_7d': 2.95664, 'market_cap': 3627606054.6238465, 'last_updated': '2020-05-21T11:12:12.000Z'}}}, {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'slug': 'litecoin', 'num_market_pairs': 609, 'date_added': '2013-04-28T00:00:00.000Z', 'tags': ['mineable'], 'max_supply': 84000000, 'circulating_supply': 64776005.7265572, 'total_supply': 64776005.7265572, 'platform': None, 'cmc_rank': 7, 'last_updated': '2020-05-21T11:12:04.000Z', 'quote': {'U ...

# %%
api_request=requests.get("https://api.coinmarketcap.com/v1/ticker/")
api=json.loads(api_request.content)
print(api)
# Out:
# {'statusCode': 410, 'error': 'Gone', 'message': 'WARNING: This API is now offline. Please switch to the new CoinMarketCap API. (https://pro.coinmarketcap.com/migrate/)'}

# %%
#to pull specified data ex:
api_request=requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=5&convert=USD&CMC_PRO_API_KEY=332c0fe8-fcfe-410a-a7bb-85c61fe285ff")
api=json.loads(api_request.content)
print(api["data"][0]["symbol"])
# Out:
# BTC

# %%
#to pull price data
api_request=requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=5&convert=USD&CMC_PRO_API_KEY=332c0fe8-fcfe-410a-a7bb-85c61fe285ff")
api=json.loads(api_request.content)
print(api["data"][0]["symbol"])
print(api["data"][0]["quote"]["USD"]["price"])
# Out:
# BTC
# 9382.6637559

# %%
#restricting ecimal point to 2digit
api_request=requests.get("https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest?start=1&limit=5&convert=USD&CMC_PRO_API_KEY=332c0fe8-fcfe-410a-a7bb-85c61fe285ff")
api=json.loads(api_request.content)
print(api["data"][1]["symbol"])
print("{0:.2f}".format(api["data"][1]["quote"]["USD"]["price"]))
# Out:
# ETH
# 207.76
